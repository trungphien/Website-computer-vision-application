# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.11  Python-3.11.5 torch-2.2.1+cu118 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
# Setup complete  (12 CPUs, 7.6 GB RAM, 48.2/97.7 GB disk)

# %% [markdown]
# ## Predict trước khi train

# %%
# !unzip /content/drive/MyDrive/Fashion.zip
# Out:
# Archive:  /content/drive/MyDrive/Fashion.zip
#    creating: Fashion/
#   inflating: Fashion/data.yaml
#    creating: Fashion/test/
#    creating: Fashion/test/images/
#   inflating: Fashion/test/images/11277842862_0.png
#   inflating: Fashion/test/images/1168591270_0.png
#   inflating: Fashion/test/images/11733104346_0.png
#   inflating: Fashion/test/images/12097601342_0.png
#   inflating: Fashion/test/images/12538623881_0.png
#   inflating: Fashion/test/images/13071224846_0.png
#   inflating: Fashion/test/images/13298533818_0.png
#   inflating: Fashion/test/images/13493236150_0.png
#   inflating: Fashion/test/images/14357179167_0.png
#   inflating: Fashion/test/images/14703055497_0.png
#   inflating: Fashion/test/images/15773954139_0.png
#   inflating: Fashion/test/images/15819201162_0.png
#   inflating: Fashion/test/images/16185717159_0.png
#   inflating: Fashion/test/images/16394582714_0.png
#   inflating: Fashion/test/images/16396625724_0.png
# ...

# %%
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('yolov8n.pt')
results = model('/content/Fashion/test/images/11277842862_0.png')
results
# Out:
# image 1/1 /content/Fashion/test/images/11277842862_0.png: 640x640 1 person, 7.8ms
# Speed: 2.7ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %% [markdown]
# ## Load dữ liệu và training

# %%
# !yolo train model=yolov8n.pt data=/content/Fashion/data.yaml epochs=30 imgsz=640
# Out:
# Ultralytics YOLOv8.2.8 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ## Predict sau train

# %%
model = YOLO('/content/drive/MyDrive/best.pt')
results = model('/content/Fashion/test/images/12097601342_0.png')
results
# Out:
# image 1/1 /content/Fashion/test/images/12097601342_0.png: 640x640 1 pant, 13.1ms
# Speed: 4.5ms preprocess, 13.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'blazer', 1: 'hoodie', 2: 'jacket', 3: 'men_jean', 4: 'men_short', 5: 'pant', 6: 'tank', 7: 'dress', 8: 'leggy', 9: 'skirt', 10: 'women_jean', 11: 'women_short'}
#  obb: None
#  orig_img: array([[[180, 180, 180],
#          [180, 180, 180],
#          [180, 180, 180],
#          ...,
#          [188, 186, 185],
#          [188, 186, 185],
#          [187, 185, 184]],
#
#         [[179, 179, 179],
#          [179, 179, 179],
#          [179, 179, 179],
#          ...,
#          [188, 186, 185],
#          [188, 186, 185],
#          [187, 185, 184]],
#
#         [[179, 179, 179],
#          [179, 179, 179],
#          [179, 179, 179],
# ...

# %% [markdown]
# ## Xuất model ra định dạng ONNX

# %%
# !yolo export model=/content/drive/MyDrive/best.pt format=onnx
# Out:
# Ultralytics YOLOv8.2.8 🚀 Python-3.10.12 torch-2.2.1+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 3007988 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 16, 8400) (6.0 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 236.5 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 9.7s, installed 1 package: ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.16.0 opset 17...
# ONNX: export success ✅ 11.4s, saved as '/content/drive/MyDrive/best.onnx' (11.7 MB)
#
# Export complete (13.6s)
# Results saved to /content/drive/MyDrive
# Predict:         yolo predict task=detect model=/content/drive/MyDrive/best.onnx imgsz=640
# ...
